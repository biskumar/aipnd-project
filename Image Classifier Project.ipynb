# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.
#
# Please make sure if you are running this notebook in the workspace that you have chosen GPU rather than CPU mode.

# %%
# Imports here
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
import torch
from torch import nn
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
data_transforms_train = transforms.Compose([
                            transforms.Resize(225),
                            transforms.RandomCrop(224),
                            transforms.RandomHorizontalFlip(),                            
                            transforms.ToTensor(),
                            transforms.Normalize([0.5, 0.5, 0.5],[0.5, 0.5, 0.5])  
])
data_transforms_valid = transforms.Compose([
                            transforms.Resize(225),
                            transforms.RandomCrop(224),
                            transforms.RandomHorizontalFlip(),                            
                            transforms.ToTensor(),
                            transforms.Normalize([0.5, 0.5, 0.5],[0.5, 0.5, 0.5])  
])
data_transforms_test = transforms.Compose([
                            transforms.Resize(225),
                            transforms.RandomCrop(224),
                            transforms.RandomHorizontalFlip(),                            
                            transforms.ToTensor(),
                            transforms.Normalize([0.5, 0.5, 0.5],[0.5, 0.5, 0.5])  
])

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(data_dir + '/train', transform=data_transforms_train)
validation_data = datasets.ImageFolder(data_dir + '/valid', transform=data_transforms_valid)
test_data = datasets.ImageFolder(data_dir + '/test', transform=data_transforms_test)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
validationloader = torch.utils.data.DataLoader(validation_data, batch_size=32)
testloader = torch.utils.data.DataLoader(test_data, batch_size=32)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.

# %%
# TODO: Build and train your network
# TODO: Build and train your network
model = models.vgg16(pretrained=True)

print(model)
print("The state dict keys: \n\n", model.state_dict().keys())
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:04<00:00, 120455941.00it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )
# The state dict keys:
#
#  odict_keys(['features.0.weight', 'features.0.bias', 'features.2.weight', 'features.2.bias', 'features.5.weight', 'features.5.bias', 'features.7.weight', 'features.7.bias', 'features.10.weight', 'features.10.bias', 'features.12.weight', 'features.12.bias', 'features.14.weight', 'features.14.bias', 'features.17.weight', 'features.17.bias', 'features.19.weight', 'features.19.bias', 'features.21.weight', 'features.21.bias', 'features.24.weight', 'features.24.bias', 'features.26.weight', 'features.26.bias', 'features.28.weight', 'features.28.bias', 'classifier.0.weight', 'classifier.0.bias', 'classifier.3.weight', 'classifier.3.bias', 'classifier.6.weight', 'classifier.6.bias'])

# %%
for param in model.parameters():
    param.requires_grad = False
classifier = nn.Sequential(OrderedDict([
    ('fc1', nn.Linear(25088, 4096)),
    ('relu', nn.ReLU()),
    ('drop', nn.Dropout()),
    ('fc2', nn.Linear(4096, 500)),
    ('relu', nn.ReLU()),
    ('fc3', nn.Linear(500, 102)),
    ('out', nn.LogSoftmax(dim=1))
]))
model.classifier = classifier

# %%
learning_rate=0.01
criterion = torch.nn.NLLLoss()
optimizer = torch.optim.Adam(model.classifier.parameters(), lr = learning_rate)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
steps = 0
print_every = 30
epochs = 3
model.to(device)
for i in range(epochs):
    model.train()
    running_loss = 0
    
    for ii, (inputs, labels) in enumerate(trainloader):
        steps += 1
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model.forward(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        if steps % print_every == 0:
            model.eval()

        valid_loss = 0
        accuracy = 0
        with torch.no_grad():
            for i, data in enumerate(validationloader):
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                log_probs = model.forward(inputs)
                batch_loss = criterion(log_probs, labels)

                valid_loss += batch_loss.item()

                # Calculate accuracy
                probs = torch.exp(log_probs)
                top_prob, top_class = probs.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

                print("Epoch: {}/{}... ".format(i+1, epochs),
                      "Training Loss: {:.3f}.. ".format(running_loss/print_every),
                      "validation Loss: {:.3f}.. ".format(valid_loss/len(validationloader)),
                      "validation Accuracy: {:.3f}".format(accuracy/len(validationloader)))

                running_loss = 0

                model.train()
# Out:
# Epoch: 1/3...  Training Loss: 0.155..  validation Loss: 22.782..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 41.566..  validation Accuracy: 0.006
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 64.189..  validation Accuracy: 0.006
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 78.946..  validation Accuracy: 0.006
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 96.068..  validation Accuracy: 0.006
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 116.439..  validation Accuracy: 0.006
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 136.244..  validation Accuracy: 0.006
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 156.810..  validation Accuracy: 0.006
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 171.354..  validation Accuracy: 0.006
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 185.886..  validation Accuracy: 0.006
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 200.951..  validation Accuracy: 0.006
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 219.078..  validation Accuracy: 0.006
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 241.099..  validation Accuracy: 0.006
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 258.809..  validation Accuracy: 0.006
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 280.221..  validation Accuracy: 0.006
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 299.053..  validation Accuracy: 0.006
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 314.803..  validation Accuracy: 0.006
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 333.723..  validation Accuracy: 0.006
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 342.817..  validation Accuracy: 0.010
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 354.925..  validation Accuracy: 0.010
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 368.019..  validation Accuracy: 0.010
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 386.301..  validation Accuracy: 0.010
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 394.454..  validation Accuracy: 0.010
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 415.288..  validation Accuracy: 0.010
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 431.190..  validation Accuracy: 0.010
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 455.298..  validation Accuracy: 0.010
# Epoch: 1/3...  Training Loss: 14.442..  validation Loss: 19.293..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 55.223..  validation Accuracy: 0.000
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 75.113..  validation Accuracy: 0.000
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 94.637..  validation Accuracy: 0.000
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 109.515..  validation Accuracy: 0.002
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 129.875..  validation Accuracy: 0.002
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 157.200..  validation Accuracy: 0.002
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 196.329..  validation Accuracy: 0.002
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 225.164..  validation Accuracy: 0.002
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 248.792..  validation Accuracy: 0.002
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 271.298..  validation Accuracy: 0.002
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 290.765..  validation Accuracy: 0.002
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 306.458..  validation Accuracy: 0.002
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 323.374..  validation Accuracy: 0.002
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 352.332..  validation Accuracy: 0.002
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 376.404..  validation Accuracy: 0.002
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 402.443..  validation Accuracy: 0.002
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 420.350..  validation Accuracy: 0.002
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 441.964..  validation Accuracy: 0.002
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 450.236..  validation Accuracy: 0.002
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 478.040..  validation Accuracy: 0.002
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 491.834..  validation Accuracy: 0.002
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 506.653..  validation Accuracy: 0.002
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 530.294..  validation Accuracy: 0.002
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 562.480..  validation Accuracy: 0.002
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 571.393..  validation Accuracy: 0.002
# Epoch: 1/3...  Training Loss: 19.663..  validation Loss: 38.590..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 87.461..  validation Accuracy: 0.000
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 118.992..  validation Accuracy: 0.000
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 139.768..  validation Accuracy: 0.000
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 171.641..  validation Accuracy: 0.000
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 211.457..  validation Accuracy: 0.000
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 249.601..  validation Accuracy: 0.000
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 300.348..  validation Accuracy: 0.000
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 329.453..  validation Accuracy: 0.000
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 349.580..  validation Accuracy: 0.000
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 365.003..  validation Accuracy: 0.000
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 395.621..  validation Accuracy: 0.000
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 422.592..  validation Accuracy: 0.000
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 443.267..  validation Accuracy: 0.013
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 491.202..  validation Accuracy: 0.013
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 532.745..  validation Accuracy: 0.013
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 580.562..  validation Accuracy: 0.013
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 618.986..  validation Accuracy: 0.013
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 634.660..  validation Accuracy: 0.013
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 641.573..  validation Accuracy: 0.019
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 664.465..  validation Accuracy: 0.020
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 685.519..  validation Accuracy: 0.022
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 697.127..  validation Accuracy: 0.022
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 718.836..  validation Accuracy: 0.022
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 741.306..  validation Accuracy: 0.022
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 761.482..  validation Accuracy: 0.022
# Epoch: 1/3...  Training Loss: 31.094..  validation Loss: 20.907..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 45.550..  validation Accuracy: 0.000
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 62.759..  validation Accuracy: 0.000
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 74.905..  validation Accuracy: 0.006
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 94.041..  validation Accuracy: 0.006
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 116.003..  validation Accuracy: 0.006
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 132.440..  validation Accuracy: 0.006
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 160.999..  validation Accuracy: 0.006
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 177.635..  validation Accuracy: 0.006
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 189.870..  validation Accuracy: 0.006
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 196.078..  validation Accuracy: 0.006
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 213.845..  validation Accuracy: 0.006
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 231.814..  validation Accuracy: 0.006
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 264.229..  validation Accuracy: 0.006
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 288.912..  validation Accuracy: 0.006
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 310.167..  validation Accuracy: 0.006
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 333.427..  validation Accuracy: 0.006
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 352.741..  validation Accuracy: 0.007
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 359.859..  validation Accuracy: 0.016
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 373.658..  validation Accuracy: 0.023
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 386.162..  validation Accuracy: 0.025
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 399.804..  validation Accuracy: 0.036
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 402.917..  validation Accuracy: 0.055
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 413.133..  validation Accuracy: 0.055
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 424.572..  validation Accuracy: 0.055
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 438.721..  validation Accuracy: 0.055
# Epoch: 1/3...  Training Loss: 11.951..  validation Loss: 5.109..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 11.829..  validation Accuracy: 0.000
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 16.957..  validation Accuracy: 0.000
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 20.243..  validation Accuracy: 0.013
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 25.917..  validation Accuracy: 0.013
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 32.018..  validation Accuracy: 0.013
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 35.573..  validation Accuracy: 0.013
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 43.929..  validation Accuracy: 0.013
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 48.192..  validation Accuracy: 0.013
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 51.959..  validation Accuracy: 0.018
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 53.240..  validation Accuracy: 0.019
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 58.067..  validation Accuracy: 0.019
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 62.220..  validation Accuracy: 0.019
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 74.459..  validation Accuracy: 0.019
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 80.418..  validation Accuracy: 0.019
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 84.981..  validation Accuracy: 0.019
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 89.864..  validation Accuracy: 0.019
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 94.017..  validation Accuracy: 0.024
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 95.482..  validation Accuracy: 0.047
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 101.658..  validation Accuracy: 0.048
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 104.808..  validation Accuracy: 0.048
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 111.686..  validation Accuracy: 0.048
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 116.437..  validation Accuracy: 0.049
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 118.802..  validation Accuracy: 0.049
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 121.110..  validation Accuracy: 0.060
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 125.592..  validation Accuracy: 0.060
# Epoch: 1/3...  Training Loss: 3.953..  validation Loss: 1.808..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 3.015..  validation Accuracy: 0.004
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 4.352..  validation Accuracy: 0.004
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 5.799..  validation Accuracy: 0.014
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 7.393..  validation Accuracy: 0.014
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 8.837..  validation Accuracy: 0.014
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 9.790..  validation Accuracy: 0.016
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 11.173..  validation Accuracy: 0.017
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 12.777..  validation Accuracy: 0.017
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 15.556..  validation Accuracy: 0.017
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 16.872..  validation Accuracy: 0.017
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 18.020..  validation Accuracy: 0.018
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 18.827..  validation Accuracy: 0.025
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 22.161..  validation Accuracy: 0.025
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 23.430..  validation Accuracy: 0.025
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 24.656..  validation Accuracy: 0.025
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 25.517..  validation Accuracy: 0.025
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 26.510..  validation Accuracy: 0.026
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 27.564..  validation Accuracy: 0.032
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 29.562..  validation Accuracy: 0.034
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 31.072..  validation Accuracy: 0.035
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 33.310..  validation Accuracy: 0.035
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 35.731..  validation Accuracy: 0.035
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 36.965..  validation Accuracy: 0.035
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 38.574..  validation Accuracy: 0.035
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 40.119..  validation Accuracy: 0.035
# Epoch: 1/3...  Training Loss: 1.181..  validation Loss: 1.855..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 2.599..  validation Accuracy: 0.006
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 3.635..  validation Accuracy: 0.006
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 4.540..  validation Accuracy: 0.016
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 5.411..  validation Accuracy: 0.020
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 6.394..  validation Accuracy: 0.022
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 7.213..  validation Accuracy: 0.026
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 7.890..  validation Accuracy: 0.029
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 8.928..  validation Accuracy: 0.030
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 11.989..  validation Accuracy: 0.030
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 13.005..  validation Accuracy: 0.030
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 14.064..  validation Accuracy: 0.030
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 14.735..  validation Accuracy: 0.030
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 16.011..  validation Accuracy: 0.031
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 16.961..  validation Accuracy: 0.031
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 17.929..  validation Accuracy: 0.031
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 18.429..  validation Accuracy: 0.034
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 18.908..  validation Accuracy: 0.036
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 19.681..  validation Accuracy: 0.044
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 20.479..  validation Accuracy: 0.044
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 21.288..  validation Accuracy: 0.048
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 22.249..  validation Accuracy: 0.048
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 23.255..  validation Accuracy: 0.048
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 24.121..  validation Accuracy: 0.049
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 24.894..  validation Accuracy: 0.050
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 25.676..  validation Accuracy: 0.050
# Epoch: 1/3...  Training Loss: 0.749..  validation Loss: 0.903..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 1.350..  validation Accuracy: 0.007
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 1.918..  validation Accuracy: 0.010
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 2.361..  validation Accuracy: 0.017
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 2.827..  validation Accuracy: 0.019
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 3.466..  validation Accuracy: 0.019
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 3.876..  validation Accuracy: 0.023
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 4.285..  validation Accuracy: 0.030
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 4.629..  validation Accuracy: 0.040
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 6.209..  validation Accuracy: 0.041
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 6.547..  validation Accuracy: 0.041
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 7.040..  validation Accuracy: 0.043
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 7.379..  validation Accuracy: 0.043
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 8.021..  validation Accuracy: 0.044
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 8.430..  validation Accuracy: 0.047
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 8.816..  validation Accuracy: 0.048
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 9.025..  validation Accuracy: 0.058
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 9.331..  validation Accuracy: 0.062
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 9.660..  validation Accuracy: 0.079
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 10.172..  validation Accuracy: 0.079
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 10.561..  validation Accuracy: 0.085
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 11.059..  validation Accuracy: 0.085
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 11.390..  validation Accuracy: 0.087
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 11.733..  validation Accuracy: 0.087
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 12.068..  validation Accuracy: 0.088
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 12.552..  validation Accuracy: 0.088
# Epoch: 1/3...  Training Loss: 0.444..  validation Loss: 0.670..  validation Accuracy: 0.004
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 1.209..  validation Accuracy: 0.004
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 1.706..  validation Accuracy: 0.004
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 2.087..  validation Accuracy: 0.011
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 2.616..  validation Accuracy: 0.011
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 3.128..  validation Accuracy: 0.012
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 3.450..  validation Accuracy: 0.018
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 3.827..  validation Accuracy: 0.028
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 4.088..  validation Accuracy: 0.042
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 4.942..  validation Accuracy: 0.047
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 5.170..  validation Accuracy: 0.047
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 5.799..  validation Accuracy: 0.048
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 6.191..  validation Accuracy: 0.048
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 6.960..  validation Accuracy: 0.052
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 7.306..  validation Accuracy: 0.053
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 7.674..  validation Accuracy: 0.053
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 8.008..  validation Accuracy: 0.056
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 8.260..  validation Accuracy: 0.061
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 8.438..  validation Accuracy: 0.081
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 9.143..  validation Accuracy: 0.082
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 9.454..  validation Accuracy: 0.085
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 10.072..  validation Accuracy: 0.087
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 10.527..  validation Accuracy: 0.090
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 10.863..  validation Accuracy: 0.090
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 11.243..  validation Accuracy: 0.090
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 11.692..  validation Accuracy: 0.090
# Epoch: 1/3...  Training Loss: 0.404..  validation Loss: 0.469..  validation Accuracy: 0.002
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 1.406..  validation Accuracy: 0.002
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 1.785..  validation Accuracy: 0.002
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 2.074..  validation Accuracy: 0.010
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 2.531..  validation Accuracy: 0.010
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 2.966..  validation Accuracy: 0.012
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 3.217..  validation Accuracy: 0.018
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 3.713..  validation Accuracy: 0.022
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 3.940..  validation Accuracy: 0.034
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 4.891..  validation Accuracy: 0.040
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 5.064..  validation Accuracy: 0.043
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 5.809..  validation Accuracy: 0.043
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 6.057..  validation Accuracy: 0.043
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 6.781..  validation Accuracy: 0.043
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 7.281..  validation Accuracy: 0.046
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 7.532..  validation Accuracy: 0.046
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 7.803..  validation Accuracy: 0.047
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 8.031..  validation Accuracy: 0.052
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 8.277..  validation Accuracy: 0.069
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 8.781..  validation Accuracy: 0.071
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 9.017..  validation Accuracy: 0.075
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 9.401..  validation Accuracy: 0.077
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 9.685..  validation Accuracy: 0.087
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 9.935..  validation Accuracy: 0.087
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 10.205..  validation Accuracy: 0.088
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 10.421..  validation Accuracy: 0.088
# Epoch: 1/3...  Training Loss: 0.371..  validation Loss: 0.481..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 1.061..  validation Accuracy: 0.001
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 1.379..  validation Accuracy: 0.001
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 1.615..  validation Accuracy: 0.006
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.954..  validation Accuracy: 0.006
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 2.380..  validation Accuracy: 0.006
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 2.621..  validation Accuracy: 0.012
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 2.807..  validation Accuracy: 0.020
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.996..  validation Accuracy: 0.025
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 3.540..  validation Accuracy: 0.031
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 3.720..  validation Accuracy: 0.035
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 4.173..  validation Accuracy: 0.035
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 4.404..  validation Accuracy: 0.035
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 4.828..  validation Accuracy: 0.038
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 5.123..  validation Accuracy: 0.040
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 5.399..  validation Accuracy: 0.040
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 5.649..  validation Accuracy: 0.041
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 5.890..  validation Accuracy: 0.044
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 6.044..  validation Accuracy: 0.059
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 6.319..  validation Accuracy: 0.066
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 6.503..  validation Accuracy: 0.073
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 6.716..  validation Accuracy: 0.076
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 6.867..  validation Accuracy: 0.087
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 7.114..  validation Accuracy: 0.087
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 7.402..  validation Accuracy: 0.087
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 7.614..  validation Accuracy: 0.087
# Epoch: 1/3...  Training Loss: 0.247..  validation Loss: 0.354..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.620..  validation Accuracy: 0.001
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.864..  validation Accuracy: 0.001
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 1.101..  validation Accuracy: 0.010
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.490..  validation Accuracy: 0.010
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.784..  validation Accuracy: 0.010
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 2.016..  validation Accuracy: 0.014
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 2.227..  validation Accuracy: 0.018
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.427..  validation Accuracy: 0.026
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 3.060..  validation Accuracy: 0.034
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 3.246..  validation Accuracy: 0.037
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 3.676..  validation Accuracy: 0.037
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 3.891..  validation Accuracy: 0.037
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 4.278..  validation Accuracy: 0.038
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 4.616..  validation Accuracy: 0.041
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 4.892..  validation Accuracy: 0.042
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 5.079..  validation Accuracy: 0.044
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 5.366..  validation Accuracy: 0.047
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 5.498..  validation Accuracy: 0.064
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 5.698..  validation Accuracy: 0.072
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 5.866..  validation Accuracy: 0.077
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 6.086..  validation Accuracy: 0.082
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 6.271..  validation Accuracy: 0.091
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 6.490..  validation Accuracy: 0.093
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 6.721..  validation Accuracy: 0.093
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 6.923..  validation Accuracy: 0.093
# Epoch: 1/3...  Training Loss: 0.252..  validation Loss: 0.363..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.770..  validation Accuracy: 0.001
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.997..  validation Accuracy: 0.001
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 1.214..  validation Accuracy: 0.007
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.577..  validation Accuracy: 0.007
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 2.199..  validation Accuracy: 0.007
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 2.415..  validation Accuracy: 0.010
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 2.622..  validation Accuracy: 0.011
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.962..  validation Accuracy: 0.013
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 3.601..  validation Accuracy: 0.020
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 3.740..  validation Accuracy: 0.030
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 4.221..  validation Accuracy: 0.030
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 4.520..  validation Accuracy: 0.030
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 4.815..  validation Accuracy: 0.031
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 5.019..  validation Accuracy: 0.034
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 5.276..  validation Accuracy: 0.034
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 5.457..  validation Accuracy: 0.037
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 5.675..  validation Accuracy: 0.042
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 5.825..  validation Accuracy: 0.055
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 6.073..  validation Accuracy: 0.060
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 6.234..  validation Accuracy: 0.065
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 6.423..  validation Accuracy: 0.070
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 6.589..  validation Accuracy: 0.085
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 6.785..  validation Accuracy: 0.087
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 6.988..  validation Accuracy: 0.087
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 7.191..  validation Accuracy: 0.087
# Epoch: 1/3...  Training Loss: 0.233..  validation Loss: 0.211..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.576..  validation Accuracy: 0.002
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.766..  validation Accuracy: 0.002
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.999..  validation Accuracy: 0.008
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.285..  validation Accuracy: 0.008
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.734..  validation Accuracy: 0.008
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.930..  validation Accuracy: 0.010
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 2.136..  validation Accuracy: 0.013
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.353..  validation Accuracy: 0.014
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.858..  validation Accuracy: 0.023
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 3.043..  validation Accuracy: 0.029
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 3.395..  validation Accuracy: 0.029
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 3.580..  validation Accuracy: 0.029
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 3.803..  validation Accuracy: 0.032
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 4.015..  validation Accuracy: 0.035
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 4.236..  validation Accuracy: 0.037
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 4.412..  validation Accuracy: 0.038
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 4.592..  validation Accuracy: 0.041
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 4.731..  validation Accuracy: 0.050
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 4.963..  validation Accuracy: 0.053
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 5.121..  validation Accuracy: 0.054
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 5.286..  validation Accuracy: 0.060
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 5.468..  validation Accuracy: 0.064
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 5.708..  validation Accuracy: 0.064
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 5.909..  validation Accuracy: 0.064
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 6.085..  validation Accuracy: 0.064
# Epoch: 1/3...  Training Loss: 0.197..  validation Loss: 0.218..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.540..  validation Accuracy: 0.001
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.747..  validation Accuracy: 0.001
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.973..  validation Accuracy: 0.010
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.308..  validation Accuracy: 0.010
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.659..  validation Accuracy: 0.010
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.837..  validation Accuracy: 0.013
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 2.016..  validation Accuracy: 0.016
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.227..  validation Accuracy: 0.016
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.603..  validation Accuracy: 0.023
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.751..  validation Accuracy: 0.029
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.992..  validation Accuracy: 0.029
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 3.172..  validation Accuracy: 0.029
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 3.416..  validation Accuracy: 0.029
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 3.604..  validation Accuracy: 0.029
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 3.832..  validation Accuracy: 0.032
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 4.002..  validation Accuracy: 0.034
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 4.187..  validation Accuracy: 0.035
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 4.320..  validation Accuracy: 0.049
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 4.515..  validation Accuracy: 0.053
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 4.673..  validation Accuracy: 0.056
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 4.837..  validation Accuracy: 0.061
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.994..  validation Accuracy: 0.070
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 5.180..  validation Accuracy: 0.070
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 5.374..  validation Accuracy: 0.070
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 5.555..  validation Accuracy: 0.070
# Epoch: 1/3...  Training Loss: 0.155..  validation Loss: 0.247..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.570..  validation Accuracy: 0.001
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.794..  validation Accuracy: 0.001
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.964..  validation Accuracy: 0.006
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.221..  validation Accuracy: 0.006
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.561..  validation Accuracy: 0.007
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.766..  validation Accuracy: 0.008
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 1.937..  validation Accuracy: 0.011
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.163..  validation Accuracy: 0.011
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.380..  validation Accuracy: 0.020
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.539..  validation Accuracy: 0.048
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.742..  validation Accuracy: 0.048
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 2.929..  validation Accuracy: 0.048
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 3.163..  validation Accuracy: 0.048
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 3.421..  validation Accuracy: 0.049
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 3.628..  validation Accuracy: 0.049
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 3.808..  validation Accuracy: 0.049
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 3.988..  validation Accuracy: 0.050
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 4.104..  validation Accuracy: 0.067
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 4.326..  validation Accuracy: 0.067
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 4.489..  validation Accuracy: 0.070
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 4.648..  validation Accuracy: 0.076
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.796..  validation Accuracy: 0.082
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 5.014..  validation Accuracy: 0.082
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 5.196..  validation Accuracy: 0.082
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 5.406..  validation Accuracy: 0.082
# Epoch: 1/3...  Training Loss: 0.248..  validation Loss: 0.236..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.583..  validation Accuracy: 0.000
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.779..  validation Accuracy: 0.000
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.981..  validation Accuracy: 0.007
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.257..  validation Accuracy: 0.007
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.527..  validation Accuracy: 0.008
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.779..  validation Accuracy: 0.013
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 1.949..  validation Accuracy: 0.017
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.128..  validation Accuracy: 0.018
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.397..  validation Accuracy: 0.026
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.560..  validation Accuracy: 0.052
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.861..  validation Accuracy: 0.052
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 3.076..  validation Accuracy: 0.052
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 3.298..  validation Accuracy: 0.052
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 3.499..  validation Accuracy: 0.052
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 3.725..  validation Accuracy: 0.052
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 3.951..  validation Accuracy: 0.052
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 4.112..  validation Accuracy: 0.054
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 4.211..  validation Accuracy: 0.073
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 4.474..  validation Accuracy: 0.073
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 4.670..  validation Accuracy: 0.075
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 4.882..  validation Accuracy: 0.084
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.994..  validation Accuracy: 0.097
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 5.229..  validation Accuracy: 0.097
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 5.425..  validation Accuracy: 0.097
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 5.633..  validation Accuracy: 0.097
# Epoch: 1/3...  Training Loss: 0.175..  validation Loss: 0.236..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.532..  validation Accuracy: 0.002
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.789..  validation Accuracy: 0.004
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.982..  validation Accuracy: 0.012
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.293..  validation Accuracy: 0.012
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.650..  validation Accuracy: 0.014
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.819..  validation Accuracy: 0.017
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 2.003..  validation Accuracy: 0.018
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.178..  validation Accuracy: 0.018
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.394..  validation Accuracy: 0.023
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.554..  validation Accuracy: 0.055
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.859..  validation Accuracy: 0.055
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 3.051..  validation Accuracy: 0.055
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 3.247..  validation Accuracy: 0.056
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 3.455..  validation Accuracy: 0.056
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 3.629..  validation Accuracy: 0.058
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 3.819..  validation Accuracy: 0.058
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 3.975..  validation Accuracy: 0.060
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 4.100..  validation Accuracy: 0.081
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 4.348..  validation Accuracy: 0.082
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 4.499..  validation Accuracy: 0.087
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 4.655..  validation Accuracy: 0.093
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.789..  validation Accuracy: 0.102
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 4.993..  validation Accuracy: 0.102
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 5.174..  validation Accuracy: 0.102
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 5.351..  validation Accuracy: 0.102
# Epoch: 1/3...  Training Loss: 0.192..  validation Loss: 0.254..  validation Accuracy: 0.001
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.512..  validation Accuracy: 0.001
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.739..  validation Accuracy: 0.001
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.936..  validation Accuracy: 0.008
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.193..  validation Accuracy: 0.008
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.487..  validation Accuracy: 0.010
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.658..  validation Accuracy: 0.010
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 1.840..  validation Accuracy: 0.010
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.018..  validation Accuracy: 0.011
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.179..  validation Accuracy: 0.017
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.344..  validation Accuracy: 0.049
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.607..  validation Accuracy: 0.049
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 2.786..  validation Accuracy: 0.049
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 3.026..  validation Accuracy: 0.049
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 3.225..  validation Accuracy: 0.050
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 3.398..  validation Accuracy: 0.050
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 3.596..  validation Accuracy: 0.050
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 3.759..  validation Accuracy: 0.053
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 3.866..  validation Accuracy: 0.075
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 4.083..  validation Accuracy: 0.083
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 4.273..  validation Accuracy: 0.084
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 4.525..  validation Accuracy: 0.085
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.679..  validation Accuracy: 0.093
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 4.853..  validation Accuracy: 0.093
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 5.033..  validation Accuracy: 0.093
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 5.213..  validation Accuracy: 0.093
# Epoch: 1/3...  Training Loss: 0.180..  validation Loss: 0.216..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.561..  validation Accuracy: 0.000
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.772..  validation Accuracy: 0.000
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.956..  validation Accuracy: 0.006
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.238..  validation Accuracy: 0.006
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.582..  validation Accuracy: 0.008
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.788..  validation Accuracy: 0.012
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 2.074..  validation Accuracy: 0.012
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.249..  validation Accuracy: 0.013
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.911..  validation Accuracy: 0.019
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 3.073..  validation Accuracy: 0.053
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 3.285..  validation Accuracy: 0.053
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 3.479..  validation Accuracy: 0.053
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 3.711..  validation Accuracy: 0.053
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 3.998..  validation Accuracy: 0.053
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 4.208..  validation Accuracy: 0.054
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 4.427..  validation Accuracy: 0.055
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 4.587..  validation Accuracy: 0.059
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 4.691..  validation Accuracy: 0.078
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 4.947..  validation Accuracy: 0.082
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 5.106..  validation Accuracy: 0.084
# ...
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.110..  validation Accuracy: 0.038
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.287..  validation Accuracy: 0.038
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 2.457..  validation Accuracy: 0.038
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 2.633..  validation Accuracy: 0.038
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 2.812..  validation Accuracy: 0.038
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 2.986..  validation Accuracy: 0.038
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 3.165..  validation Accuracy: 0.038
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 3.329..  validation Accuracy: 0.038
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 3.470..  validation Accuracy: 0.043
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 3.689..  validation Accuracy: 0.043
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 3.853..  validation Accuracy: 0.043
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 4.025..  validation Accuracy: 0.043
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.170..  validation Accuracy: 0.043
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 4.357..  validation Accuracy: 0.043
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 4.522..  validation Accuracy: 0.043
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 4.702..  validation Accuracy: 0.043
# Epoch: 1/3...  Training Loss: 0.355..  validation Loss: 0.206..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.385..  validation Accuracy: 0.001
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.569..  validation Accuracy: 0.001
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.760..  validation Accuracy: 0.001
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 0.952..  validation Accuracy: 0.001
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.217..  validation Accuracy: 0.001
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.396..  validation Accuracy: 0.001
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 1.580..  validation Accuracy: 0.001
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 1.741..  validation Accuracy: 0.001
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 1.966..  validation Accuracy: 0.001
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.106..  validation Accuracy: 0.034
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.283..  validation Accuracy: 0.034
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 2.453..  validation Accuracy: 0.034
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 2.630..  validation Accuracy: 0.034
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 2.951..  validation Accuracy: 0.034
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 3.124..  validation Accuracy: 0.034
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 3.274..  validation Accuracy: 0.034
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 3.432..  validation Accuracy: 0.035
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 3.567..  validation Accuracy: 0.042
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 3.785..  validation Accuracy: 0.042
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 3.949..  validation Accuracy: 0.042
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 4.122..  validation Accuracy: 0.042
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.268..  validation Accuracy: 0.042
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 4.445..  validation Accuracy: 0.044
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 4.606..  validation Accuracy: 0.046
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 4.787..  validation Accuracy: 0.046
# Epoch: 1/3...  Training Loss: 0.194..  validation Loss: 0.324..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.527..  validation Accuracy: 0.000
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.807..  validation Accuracy: 0.000
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 1.152..  validation Accuracy: 0.005
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.368..  validation Accuracy: 0.005
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.870..  validation Accuracy: 0.005
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 2.119..  validation Accuracy: 0.005
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 2.329..  validation Accuracy: 0.005
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.585..  validation Accuracy: 0.005
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.962..  validation Accuracy: 0.006
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 3.144..  validation Accuracy: 0.030
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 3.450..  validation Accuracy: 0.030
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 3.659..  validation Accuracy: 0.030
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 4.401..  validation Accuracy: 0.030
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 4.869..  validation Accuracy: 0.030
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 5.242..  validation Accuracy: 0.030
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 5.411..  validation Accuracy: 0.030
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 5.575..  validation Accuracy: 0.031
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 5.706..  validation Accuracy: 0.038
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 5.865..  validation Accuracy: 0.038
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 6.183..  validation Accuracy: 0.038
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 6.375..  validation Accuracy: 0.038
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 6.618..  validation Accuracy: 0.038
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 6.801..  validation Accuracy: 0.041
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 6.963..  validation Accuracy: 0.043
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 7.171..  validation Accuracy: 0.043
# Epoch: 1/3...  Training Loss: 0.182..  validation Loss: 0.232..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.408..  validation Accuracy: 0.001
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.626..  validation Accuracy: 0.001
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.839..  validation Accuracy: 0.005
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.041..  validation Accuracy: 0.005
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.323..  validation Accuracy: 0.005
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.543..  validation Accuracy: 0.005
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 1.754..  validation Accuracy: 0.005
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 1.916..  validation Accuracy: 0.005
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.103..  validation Accuracy: 0.007
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.245..  validation Accuracy: 0.037
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.448..  validation Accuracy: 0.037
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 2.621..  validation Accuracy: 0.037
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 2.867..  validation Accuracy: 0.037
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 3.302..  validation Accuracy: 0.037
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 3.474..  validation Accuracy: 0.037
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 3.626..  validation Accuracy: 0.037
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 3.785..  validation Accuracy: 0.038
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 3.917..  validation Accuracy: 0.046
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 4.099..  validation Accuracy: 0.046
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 4.266..  validation Accuracy: 0.046
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 4.444..  validation Accuracy: 0.046
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.591..  validation Accuracy: 0.046
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 4.767..  validation Accuracy: 0.048
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 4.972..  validation Accuracy: 0.049
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 5.155..  validation Accuracy: 0.049
# Epoch: 1/3...  Training Loss: 0.182..  validation Loss: 0.272..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.482..  validation Accuracy: 0.000
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.672..  validation Accuracy: 0.000
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.877..  validation Accuracy: 0.005
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.068..  validation Accuracy: 0.005
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.273..  validation Accuracy: 0.005
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.450..  validation Accuracy: 0.005
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 1.636..  validation Accuracy: 0.005
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 1.797..  validation Accuracy: 0.005
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.006..  validation Accuracy: 0.005
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.143..  validation Accuracy: 0.038
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.321..  validation Accuracy: 0.038
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 2.492..  validation Accuracy: 0.038
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 2.671..  validation Accuracy: 0.038
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 2.867..  validation Accuracy: 0.038
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 3.038..  validation Accuracy: 0.038
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 3.187..  validation Accuracy: 0.038
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 3.339..  validation Accuracy: 0.041
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 3.461..  validation Accuracy: 0.050
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 3.641..  validation Accuracy: 0.050
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 3.807..  validation Accuracy: 0.050
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 3.982..  validation Accuracy: 0.050
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.139..  validation Accuracy: 0.050
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 4.345..  validation Accuracy: 0.050
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 4.510..  validation Accuracy: 0.050
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 4.693..  validation Accuracy: 0.050
# Epoch: 1/3...  Training Loss: 0.156..  validation Loss: 0.296..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.578..  validation Accuracy: 0.002
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.822..  validation Accuracy: 0.002
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 1.088..  validation Accuracy: 0.005
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.310..  validation Accuracy: 0.005
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.667..  validation Accuracy: 0.005
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.901..  validation Accuracy: 0.005
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 2.271..  validation Accuracy: 0.006
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 2.441..  validation Accuracy: 0.006
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 3.018..  validation Accuracy: 0.006
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 3.172..  validation Accuracy: 0.030
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 3.810..  validation Accuracy: 0.030
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 3.981..  validation Accuracy: 0.030
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 4.426..  validation Accuracy: 0.030
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 4.641..  validation Accuracy: 0.030
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 4.863..  validation Accuracy: 0.030
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 5.011..  validation Accuracy: 0.030
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 5.168..  validation Accuracy: 0.031
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 5.296..  validation Accuracy: 0.043
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 5.672..  validation Accuracy: 0.043
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 5.848..  validation Accuracy: 0.043
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 6.065..  validation Accuracy: 0.043
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 6.251..  validation Accuracy: 0.043
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 6.483..  validation Accuracy: 0.046
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 6.673..  validation Accuracy: 0.047
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 7.280..  validation Accuracy: 0.047
# Epoch: 1/3...  Training Loss: 0.296..  validation Loss: 0.210..  validation Accuracy: 0.000
# Epoch: 2/3...  Training Loss: 0.000..  validation Loss: 0.457..  validation Accuracy: 0.001
# Epoch: 3/3...  Training Loss: 0.000..  validation Loss: 0.655..  validation Accuracy: 0.001
# Epoch: 4/3...  Training Loss: 0.000..  validation Loss: 0.842..  validation Accuracy: 0.005
# Epoch: 5/3...  Training Loss: 0.000..  validation Loss: 1.033..  validation Accuracy: 0.005
# Epoch: 6/3...  Training Loss: 0.000..  validation Loss: 1.230..  validation Accuracy: 0.005
# Epoch: 7/3...  Training Loss: 0.000..  validation Loss: 1.422..  validation Accuracy: 0.005
# Epoch: 8/3...  Training Loss: 0.000..  validation Loss: 1.801..  validation Accuracy: 0.005
# Epoch: 9/3...  Training Loss: 0.000..  validation Loss: 1.963..  validation Accuracy: 0.005
# Epoch: 10/3...  Training Loss: 0.000..  validation Loss: 2.212..  validation Accuracy: 0.006
# Epoch: 11/3...  Training Loss: 0.000..  validation Loss: 2.377..  validation Accuracy: 0.038
# Epoch: 12/3...  Training Loss: 0.000..  validation Loss: 2.866..  validation Accuracy: 0.038
# Epoch: 13/3...  Training Loss: 0.000..  validation Loss: 3.037..  validation Accuracy: 0.038
# Epoch: 14/3...  Training Loss: 0.000..  validation Loss: 3.248..  validation Accuracy: 0.038
# Epoch: 15/3...  Training Loss: 0.000..  validation Loss: 3.485..  validation Accuracy: 0.038
# Epoch: 16/3...  Training Loss: 0.000..  validation Loss: 3.655..  validation Accuracy: 0.038
# Epoch: 17/3...  Training Loss: 0.000..  validation Loss: 3.841..  validation Accuracy: 0.038
# Epoch: 18/3...  Training Loss: 0.000..  validation Loss: 3.991..  validation Accuracy: 0.041
# Epoch: 19/3...  Training Loss: 0.000..  validation Loss: 4.101..  validation Accuracy: 0.054
# Epoch: 20/3...  Training Loss: 0.000..  validation Loss: 4.298..  validation Accuracy: 0.054
# Epoch: 21/3...  Training Loss: 0.000..  validation Loss: 4.461..  validation Accuracy: 0.054
# Epoch: 22/3...  Training Loss: 0.000..  validation Loss: 4.637..  validation Accuracy: 0.054
# Epoch: 23/3...  Training Loss: 0.000..  validation Loss: 4.786..  validation Accuracy: 0.054
# Epoch: 24/3...  Training Loss: 0.000..  validation Loss: 4.961..  validation Accuracy: 0.055
# Epoch: 25/3...  Training Loss: 0.000..  validation Loss: 5.125..  validation Accuracy: 0.056
# Epoch: 26/3...  Training Loss: 0.000..  validation Loss: 5.459..  validation Accuracy: 0.056

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
def test(model, testloader):
    correct = 0
    total = 0
    model.to(device)
    with torch.no_grad():
        for inputs, labels in testloader:
            model.eval()
            total += len(labels)
            inputs, label = inputs.to(device), labels.to(device)
            output = model.forward(inputs)
            predictions = torch.exp(output).max(dim=1)[1]
            for i in range(len(predictions)):
                if predictions[i] == label[i]:
                    correct +=1
        print('{} correct out of {}, {:.2f}% accurate'.format(correct, total, (correct/total) * 100))

test(model, testloader)
# Out:
# 51 correct out of 819, 6.23% accurate

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_data.class_to_idx
checkpoint = {
    'model': models.vgg16(pretrained=True),
    'features': model.features,
    'classifier': model.classifier,
    'state_dict': model.state_dict(),
    'class_to_idx': model.class_to_idx,
    'epochs': 24
}
torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = checkpoint['model']
    model.features = checkpoint['features']
    model.classifier = checkpoint['classifier']
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    epochs = checkpoint['epochs']
    return model, epochs
load_checkpoint('checkpoint.pth')
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
test(model, testloader)
# Out:
# 48 correct out of 819, 5.86% accurate

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    im = Image.open(image).convert('RGB')
    # TODO: Process a PIL image for use in a PyTorch model
    im = im.resize((256, 256))
    cropped_im = im.crop((0, 0, 249, 249))
    im_to_np = np.array(cropped_im)
    im_to_np = (im_to_np / 45) - np.array([0.485, 0.456, 0.406]) / np.array([0.229, 0.224, 0.225])
    im_to_np = im_to_np.transpose(2, 0, 1)
    return torch.from_numpy(im_to_np)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    model.to(device)
    image = process_image(image_path).unsqueeze_(0)
    with torch.no_grad():
        model.eval()
        image = image.float().to(device)
        output = model.forward(image)
        prediction = torch.exp(output).data[0].topk(5)
        return prediction


probs, classes = predict('flowers/test/1/image_06743.jpg', model)
probs, classes = probs.cpu().numpy(), classes.cpu().numpy()
print(probs)
# Out:
# [ 0.03199149  0.02520952  0.0224792   0.02120218  0.02047848]

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
names = []
indexes = []
for cat in classes:
    indexes.append(model.class_to_idx[str(cat + 1)])
for name in indexes:
    names.append(cat_to_name[str(name + 1)])

imshow(torch.DoubleTensor(process_image('flowers/test/1/image_06743.jpg')), plt.subplot(1,1,1), names[0]);
fig, ax = plt.subplots()
y = np.arange(len(names))
print(y)
ax.barh(y, probs, align='center')
ax.set_title('Top 5 Predictions')
ax.set_yticks(np.arange(len(probs)))
ax.set_yticks(np.arange(len(probs)))
# Out:
# [0 1 2 3 4]
# [<matplotlib.axis.YTick at 0x7f15ce5f2b70>,
#  <matplotlib.axis.YTick at 0x7f15ce5f2240>,
#  <matplotlib.axis.YTick at 0x7f15ce5f25f8>,
#  <matplotlib.axis.YTick at 0x7f15cc48e898>,
#  <matplotlib.axis.YTick at 0x7f15cc48eef0>]
